# %%
import pandas as pd
action_tracker=pd.read_csv('Action Tracker.csv')

# %%
action_tracker
# Out:
#        Action ID Action start date Action Status      Action Type  \
# 0              1        25-08-2019  Not Attained   Price Increase
# 1              1        25-08-2019  Not Attained   Price Increase
# 2              1        25-08-2019  Not Attained   Price Increase
# 3              1        25-08-2019  Not Attained   Price Increase
# 4              1        25-08-2019  Not Attained   Price Increase
# ...          ...               ...           ...              ...
# 12153         41        01-03-2019      Attained  Volume Increase
# 12154         41        01-03-2019      Attained  Volume Increase
# 12155         41        01-03-2019      Attained  Volume Increase
# 12156         40        01-07-2019  Not Attained  Volume Increase
# 12157         40        01-07-2019  Not Attained  Volume Increase
#
#       Action_end_date                Axis Commission grp  \
# 0          31-12-2019   Sales Office - 13              P
# ...
